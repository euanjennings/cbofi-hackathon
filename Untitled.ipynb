# %%
import zipfile
import os
from IPython.display import HTML

# Files to include in the zip
files = [
    'main_eval.ipynb'
]

zip_name = 'main_eval.zip'

with zipfile.ZipFile(zip_name, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for file in files:
        if os.path.exists(file):
            zipf.write(file)
            print(f'✅ Added: {file}')
        else:
            print(f'❌ Missing: {file}')

print(f'\nZip created: {zip_name}')
# Out:
# ✅ Added: main_eval.ipynb
#
# Zip created: main_eval.zip

# %%
from IPython.display import HTML
HTML('<a href="main.zip" download="main_eval.zip" target="_blank">📦 Download main.zip</a>')
# Out:
# <a href="main.zip" download="main_eval.zip" target="_blank">📦 Download main.zip</a>
